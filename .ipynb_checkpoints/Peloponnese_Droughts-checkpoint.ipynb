# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 50)
pd.__version__

import matplotlib.pyplot as plt

#setups
# %matplotlib inline

# %%
#Matplotlib setups
from matplotlib.ticker import FuncFormatter

# %%
#more Matplotlib setups
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>Agency FB: <span style='font-family:Agency FB; font-size: 24px;'>Agency FB</p>
# <p>Algerian: <span style='font-family:Algerian; font-size: 24px;'>Algerian</p>
# <p>Arial: <span style='font-family:Arial; font-size: 24px;'>Arial</p>
# <p>Arial Rounded MT Bold: <span style='font-family:Arial Rounded MT Bold; font-size: 24px;'>Arial Rounded MT Bold</p>
# <p>Bahnschrift: <span style='font-family:Bahnschrift; font-size: 24px;'>Bahnschrift</p>
# <p>Baskerville Old Face: <span style='font-family:Baskerville Old Face; font-size: 24px;'>Baskerville Old Face</p>
# <p>Bauhaus 93: <span style='font-family:Bauhaus 93; font-size: 24px;'>Bauhaus 93</p>
# <p>Bell MT: <span style='font-family:Bell MT; font-size: 24px;'>Bell MT</p>
# <p>Berlin Sans FB: <span style='font-family:Berlin Sans FB; font-size: 24px;'>Berlin Sans FB</p>
# <p>Berlin Sans FB Demi: <span style='font-family:Berlin Sans FB Demi; font-size: 24px;'>Berlin Sans FB Demi</p>
# ...

# %%
#more Matplotlib setups

plt.rcdefaults()
plt.rcParams.update({
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
})

# %%
file_path = 'C:\\Users\\c.marinou\\Documents\\GitHub\\Purkagies\\peloponnisos\\SPEI_37.75_22.25.csv'

# %%
# Read the CSV file into a DataFrame
df = pd.read_csv(file_path)

# %%
# FIltering only the month of October
oct_df=df[df.DATA.str.contains( 'Oct',na=False)]

# %%
# Keeping the columns with the Date and the index I want
oct_df=oct_df[['DATA','SPEI_12']]

# %%
# Keeping the year frome the date
oct_df['date'] = pd.to_datetime(oct_df['DATA'])
# Out:
# C:\Users\c.marinou\AppData\Local\Temp\ipykernel_23964\1712615696.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   oct_df['date'] = pd.to_datetime(oct_df['DATA'])

# %%
oct_df['year'] = oct_df['date'].dt.year

# %%
oct_df=oct_df.drop(columns=['date','DATA'])

# %%
oct_df=oct_df.reset_index().drop(['index'],axis=1)

# %%
# Making the graph 

sp12 = oct_df.plot(kind='bar',x='year',y='SPEI_12',figsize=(20,5),rot=45, color='brown', alpha=.8, legend=True)

# putting a defining line in -1 which shows the value from which droughts start
y_value = -1  
sp12.axhline(y=y_value, color='dimgray', linestyle='--', label=f'Y = {y_value}')


sp12.set_title('Peloponnisos Drought Events 1950-2023', fontsize=15, fontweight='bold')
#set a subtitle
plt.suptitle('12-month average of SPEI', fontsize=11, color='dimgray', fontweight='bold')
# Out:
# Text(0.5, 0.98, '12-month average of SPEI')

# %%
p12 = oct_df.plot(x='year', y='SPEI_12',figsize=(10,5),rot=45, color='brown', alpha=.8, legend=True)
p12.set_title('A single plot')

y_value = -1  
p12.axhline(y=y_value, color='dimgray', linestyle='--', label=f'Y = {y_value}')

# %%
p12 = oct_df.plot(x='year',y='SPEI_12',figsize=(10,5),rot=45, color='brown', alpha=.8, legend=True)

y_value = -1  
p12.axhline(y=-1, color='dimgray', linestyle='--', label=f'Y = {y_value}')
p12.axhline(y=0, color='dimgray',  label=f'Y = {y_value}')


p12.fill_between(oct_df['year'], oct_df['SPEI_12'], y_value, where=(oct_df['SPEI_12'] < y_value),
                 interpolate=True, color='brown', alpha=0.5)
p12.set_title('Peloponnese')
p12.legend()

plt.show()

# %%
# df_group_med= df_group.groupby('year').median()

# %%
# df_group_med= df_group_med.reset_index()

# %%
# df_group_sort=df_group.groupby('year').mean().sort_values('SPEI_48')
# df_group_sort

# %%
# df_group_sort = df_group_sort.reset_index()
# df_group_sort

# %%
# checking the graph in mean

# sp48 = df_group_mean.plot(kind='bar',x='year',y='SPEI_48',figsize=(20,5),rot=45, color='firebrick', alpha=.8, legend=True)

# sp48.set_title('Peloponnisos Drought Events 1950-2023', fontsize=15, fontweight='bold')
# #set a subtitle
# plt.suptitle('48-month average of SPEI', fontsize=11, color='dimgray', fontweight='bold')

# %%
# # checking the graph with median
# sp48 = df_group_med.plot(kind='bar',x='year',y='SPEI_48',figsize=(20,5),rot=45, color='firebrick', alpha=.8, legend=True)

# sp48.set_title('Peloponnisos Drought Events 1950-2023', fontsize=15, fontweight='bold')
# #set a subtitle
# plt.suptitle('48-month average of SPEI', fontsize=11, color='dimgray', fontweight='bold')

# %%
# sp24 = df_group_med.plot(kind='bar',x='year',y='SPEI_24',figsize=(20,5),rot=45, color='firebrick', alpha=.8, legend=True)

# sp24.set_title('Peloponnisos Drought Events 1950-2023', fontsize=15, fontweight='bold')
# #set a subtitle
# plt.suptitle('48-month average of SPEI', fontsize=11, color='dimgray', fontweight='bold')

# %%
# sp3 = df_group_med.plot(kind='bar',x='year',y='SPEI_3',figsize=(20,5),rot=45, color='firebrick', alpha=.8, legend=True)

# sp3.set_title('Peloponnisos Drought Events 1950-2023', fontsize=15, fontweight='bold')
# #set a subtitle
# plt.suptitle('3-month average of SPEI', fontsize=11, color='dimgray', fontweight='bold')

# %%
# df['SPEI_48'].mean()

# %%
oct_df = oct_df.rename(columns={oct_df.columns[1]:'peloponnese'})

# %%
oct_df.to_csv('peloponnese_df.csv',index=False)

# %%
# index_values = df_group.index

# %%
# df['SPEI_48'].median()

# %%
# df_group.plot(kind='bar',x=index_values,y='SPEI_48',figsize=(20,5),rot=30)
