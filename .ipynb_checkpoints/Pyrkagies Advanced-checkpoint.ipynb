# %%
import pandas as pd
import os
pd.set_option('display.max_rows', 10)
pd.__version__
# Out:
# '2.0.0'

# %%
def read_excel(filename):
    try:
        df = pd.read_excel(filename, header=1)
    except Exception as e:
        print(f"cannot read {filename}. Error: {e}")
    return df

# %%
def read_all_excels(path, selection):
    ''' This function:
     - reads all the data of forest fires
     - concatenates them
     - removes unwanted columns
     - turns strings into numbers
     '''
#     this is where we'll save all the dataframes when we read them
    list_of_dfs=[]
#     lists the files of the path
    files = os.listdir(path)
#     filters the files we want to read
    excel_files = [f for f in files if f.endswith('.xlsx')]
#     loop through the files
    for file in excel_files:
#          prints message for us to see the progress
        print(f"Reading file: {file}")
#          reads the each file
        df=read_excel(f"{path}/{file}")
#          turn strings into numbers (but keep the categorical strings into strings)
#         df = df.apply(lambda x: pd.to_numeric(x.astype(str), errors='ignore'))
        list_of_dfs.append(df)
    forest_fires = pd.concat(list_of_dfs).reset_index(drop=True)
    forest_fires = forest_fires[selection]
    return forest_fires

# %%
selected_columns=[ 'X-ENGAGE',
                       'Y-ENGAGE',                 'Υπηρεσία',
                          'Νομός',         'Ημερ/νία Έναρξης',
                    'Ώρα Έναρξης',      'Ημερ/νία Κατασβεσης',
                 'Ώρα Κατάσβεσης',                'Δασαρχείο',
                          'Δήμος',                  'Περιοχή',
                      'Διεύθυνση',                     'Δάση',
                  'Δασική Έκταση',                     'Άλση',
              'Χορτ/κές Εκτάσεις',         'Καλάμια - Βάλτοι',
             'Γεωργικές Εκτάσεις', 'Υπολλείματα Καλλιεργειών',
                 'Σκουπι-δότοποι']

# %%
pwd
# Out:
# 'C:\\Users\\c.marinou\\Documents\\GitHub\\Purkagies'

# %%
read_all_excels('C:\\Users\\c.marinou\\Documents\\GitHub\\Purkagies', selected_columns)
# Out:
# Reading file: Dasikes_Pyrkagies_2017_v1.3.xlsx
# Reading file: Dasikes_Pyrkagies_2018_v1.4.xlsx
# Reading file: Dasikes_Pyrkagies_2019_v1.5.xlsx
# Reading file: Dasikes_Pyrkagies_2020.xlsx
# Reading file: Dasikes_Pyrkagies_2021.xlsx
# Reading file: Dasikes_Pyrkagies_2022_v1.7a.xlsx
#         X-ENGAGE   Y-ENGAGE      Υπηρεσία     Νομός Ημερ/νία Έναρξης
# 0            NaN        NaN  Π.Κ. ΚΑΛΑΜΟΥ   ΑΤΤΙΚΗΣ       2017-04-09  \
# 1            NaN        NaN  Π.Κ. ΚΑΛΑΜΟΥ   ΑΤΤΙΚΗΣ       2017-07-05
# 2            NaN        NaN  Π.Κ. ΚΑΛΑΜΟΥ   ΑΤΤΙΚΗΣ       2017-08-13
# 3            NaN        NaN  Π.Κ. ΚΑΛΑΜΟΥ   ΑΤΤΙΚΗΣ       2017-10-24
# 4            NaN        NaN  Π.Κ. ΚΑΛΑΜΟΥ   ΑΤΤΙΚΗΣ       2017-10-24
# ...          ...        ...           ...       ...              ...
# 59026  20.687734  37.846745  Π.Κ. ΕΛΑΤΙΩΝ  ΖΑΚΥΝΘΟΥ       2022-07-05
# 59027  20.729318  37.879112  Π.Κ. ΕΛΑΤΙΩΝ  ΖΑΚΥΝΘΟΥ       2022-07-27
# 59028  20.687128  37.792744  Π.Κ. ΕΛΑΤΙΩΝ  ΖΑΚΥΝΘΟΥ       2022-07-29
# 59029   20.70619  37.888864  Π.Κ. ΕΛΑΤΙΩΝ  ΖΑΚΥΝΘΟΥ       2022-08-10
# 59030  20.656907  37.823133  Π.Κ. ΕΛΑΤΙΩΝ  ΖΑΚΥΝΘΟΥ       2022-10-19
#
#       Ώρα Έναρξης Ημερ/νία Κατασβεσης Ώρα Κατάσβεσης Δασαρχείο        Δήμος
# 0           12:44          2017-04-09          16:31       NaN    Δ. ΩΡΩΠΟΥ  \
# 1           17:16          2017-07-08          08:05       NaN    Δ. ΩΡΩΠΟΥ
# 2           16:16          2017-09-11          20:00       NaN    Δ. ΩΡΩΠΟΥ
# 3           05:17          2017-10-24          08:06       NaN    Δ. ΩΡΩΠΟΥ
# 4           08:23          2017-10-24          19:30       NaN    Δ. ΩΡΩΠΟΥ
# ...           ...                 ...            ...       ...          ...
# 59026       17:30          2022-07-05          18:12       NaN  Δ. ΖΑΚΥΝΘΟΥ
# 59027       16:15          2022-07-27          16:49       NaN  Δ. ΖΑΚΥΝΘΟΥ
# 59028       15:50          2022-07-29          18:51       NaN  Δ. ΖΑΚΥΝΘΟΥ
# 59029       10:45          2022-08-17          18:44       NaN  Δ. ΖΑΚΥΝΘΟΥ
# 59030       14:24          2022-10-19          19:24       NaN  Δ. ΖΑΚΥΝΘΟΥ
#
#           Περιοχή                                Διεύθυνση    Δάση
# 0         ΚΑΛΑΜΟΣ                         ΡΕΜΑ ΜΑΥΡΟΔΗΛΕΣΙ     0.0  \
# 1      ΚΑΠΑΝΔΡΙΤΙ  ΟΔΟΣ ΚΑΖΑΝΤΖΑΚΗ ΘΕΣΗ ΛΙΜΝΕΣ - ΜΕΤΟΧΙ ΡΗ     0.0
# 2         ΚΑΛΑΜΟΣ                ΘΕΣΗ ΛΑΔΟΜΑΝΔΡΑ - ΚΑΛΑΜΟΣ  5000.0
# 3      ΚΑΠΑΝΔΡΙΤΙ                                ΜΙΚΡΟΧΩΡΙ     0.0
# 4      ΚΑΠΑΝΔΡΙΤΙ                  ΜΑΥΡΗ ΩΡΑ -ΚΑΠΑΝΔΡΙΤΙΟΥ     0.0
# ...           ...                                      ...     ...
# 59026    ΟΡΘΟΝΙΕΣ                            Τ.Κ. ΟΡΘΟΝΙΩΝ     0.0
# 59027         NaN                             Τ.Κ. ΒΟΛΙΜΩΝ     0.0
# 59028         NaN                             Τ.Κ. ΕΛΑΤΙΩΝ     0.5
# 59029     ΒΟΛΙΜΕΣ                               ΜΕΓΑ ΑΛΩΝΙ     0.0
# 59030      ΜΑΡΙΕΣ                                 ΚΑΤΩΝΤΡΙ     0.0
#
#        Δασική Έκταση  Άλση  Χορτ/κές Εκτάσεις  Καλάμια - Βάλτοι
# 0                2.0   0.0                0.0               0.0  \
# 1               18.0   0.0                0.0               0.0
# 2            15000.0   0.0                0.0               0.0
# 3                1.5   0.0                0.0               0.0
# 4                1.5   0.0                0.0               0.0
# ...              ...   ...                ...               ...
# 59026            0.0   0.0                0.0               0.0
# 59027            0.0   0.0                0.0               0.0
# 59028            0.0   0.0                0.0               0.0
# 59029           70.0   0.0                0.0               0.0
# 59030            0.0   0.0                0.0               0.0
#
#        Γεωργικές Εκτάσεις  Υπολλείματα Καλλιεργειών  Σκουπι-δότοποι
# 0                    0.00                       0.0             0.0
# 1                    0.00                       0.0             0.0
# 2                  500.00                       0.0             0.0
# 3                    0.00                       0.0             0.0
# 4                    0.00                       0.0             0.0
# ...                   ...                       ...             ...
# 59026                0.10                       0.0             0.0
# 59027                0.01                       0.0             0.0
# 59028                0.00                       0.0             0.0
# 59029               10.00                       0.0             0.0
# 59030                1.00                       0.0             0.0
#
# [59031 rows x 20 columns]
