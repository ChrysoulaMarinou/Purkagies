# %%
import netCDF4 as nc
import pandas as pd
import numpy as np
import re
import difflib
pd.set_option('display.max_rows', 2500)

# %%
dataset =nc.Dataset('cdinx_m_euu_20210101_20211221_t.nc')

# %%
variable_data = dataset.variables['variable_name'][:]
df = pd.DataFrame(variable_data)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Source_Software: dbinterface.py, dbexport.py, netcdf_handling.py
#     creator_name: Carolina Arias Munoz
#     Conventions: CF-1.6
#     _CoordSysBuilder: ucar.nc2.dataset.conv.CF1Convention
#     date_created: 2023-04-05
#     01.title: Combined Drought Indicator (CDI), v.3.0.0
# ...

# %%
pd.read_csv('jrc_edo_cdi_GR_20220321.csv')
# Out:
#                             Please read Terms and Conditions of Access and Use of EDO data at https://edo.jrc.ec.europa.eu/edov2/php/index.php?id=1044
# cell_id  latitude longitude                                                cdi
# 20821699 39.7708  19.7708                                                    5
# 20821700 39.7708  19.8125                                                    5
# 20821701 39.7708  19.8542                                                    5
# 20821702 39.7708  19.8958                                                    5
# 20821703 39.7708  19.9375                                                    5
# 20821725 39.8125  19.8542                                                    2
# 20925799 39.5208  20.2708                                                    5
# 20925800 39.5208  20.3125                                                    5
# 20925801 39.5208  20.3542                                                    5
# ...
